# %% [markdown]
# # Vertical Chat
# A sample how to build a chat for small business using:
#
# * GPT 35
# * Panel
# * OpenAI
#
#
# This is just a simple sample to start to understand how the OpenAI API works, and how to create Prompts. It Is really far from beign a complete solution.
# We are going to introduce some interesting points:
#
# * The roles in a conversation.
# * How is the conversations’ memory preserved?
#
# Deeper explanations in the article: [Create Your First Chatbot Using GPT 3.5, OpenAI, Python and Panel.](https://medium.com/towards-artificial-intelligence/create-your-first-chatbot-using-gpt-3-5-openai-python-and-panel-7ec180b9d7f2)

# %%
#!pip install jupyter_bokeh

# %%
# Read open ai text key
with open('openai-api.txt', 'r') as file:
    key = file.read().replace('\n', '')

# %%
#if you need an API Key from OpenAI
#https://platform.openai.com/account/api-keys

from openai import OpenAI
import os

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=key,
)

def continue_conversation(messages, temperature=0):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=temperature,
    )
    #print(str(response.choices[0].message["content"]))
    return response.choices[0].message.content

# %%
def add_prompts_conversation(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''

    #Append to the context the User prompt.
    context.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation(context)

    #Add the response to the context.
    context.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels)

# %%
#Creating the prompt
#read and understand it.
import panel as pn  # GUI

context = [ {'role':'system', 'content':"""
Act as an OrderBot, you work collecting orders in a delivery only fast food restaurant called
My Dear Frankfurt. \
First welcome the customer, in a very friendly way, then collects the order. \
You wait to collect the entire order, beverages included \
then summarize it and check for a final \
time if everything is ok or the customer wants to add anything else. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very friendly style. \
The menu includes \
burger  12.95, 10.00, 7.00 \
frankfurt   10.95, 9.25, 6.50 \
sandwich   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
martra sausage 3.00 \
canadian bacon 3.50 \
romesco sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
vichy catalan 5.00 \
"""} ]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <ipython-input-6-0bc33184113e>:36: UserWarning: Using Panel interactively in Colab notebooks requires the jupyter_bokeh package to be installed. Install it with:
#
#     !pip install jupyter_bokeh
#
# and try again.
#   pn.extension()
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='88be1fa3-e9cf-438a-9001-5b1da9a96af3'>
# ...

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %%
context = [ {'role':'system', 'content':"""
Act as a Gym Instructor. Your role is to guide customers in selecting a workout routine.

1. First, welcome the customer in a friendly and motivational way.
2. Then, help them choose **three exercises per muscle group** from the following list:

   **Chest:**
   - Bench Press
   - Incline Dumbbell Press
   - Cable Flys
   - Push-ups
   - Dumbbell Pullover

   **Shoulders:**
   - Overhead Press
   - Lateral Raises
   - Face Pulls
   - Arnold Press
   - Upright Rows

   **Legs:**
   - Squats
   - Lunges
   - Deadlifts
   - Leg Press
   - Bulgarian Split Squats

   **Glutes:**
   - Hip Thrusts
   - Glute Bridges
   - Cable Kickbacks
   - Romanian Deadlifts
   - Step-ups

   **Biceps:**
   - Barbell Curl
   - Hammer Curl
   - Concentration Curl
   - Preacher Curl
   - Chin-ups

   **Triceps:**
   - Dips
   - Tricep Rope Pushdown
   - Skull Crushers
   - Close-Grip Bench Press
   - Overhead Tricep Extension

   **Back:**
   - Pull-ups
   - Lat Pulldown
   - Bent-over Rows
   - Seated Cable Rows
   - Deadlifts

3. Encourage them to complete their selection before proceeding.
4. Summarize their final workout plan and check if they want to make any changes.
5. End the conversation with a motivational note, reminding them to stay consistent and enjoy their workout.
6. Keep your responses short, friendly, and encouraging.

**Example Interaction:**
Customer: "Hey, I need a good workout for chest, shoulders, and legs."
Instructor: "Great choice. Here are some options. Pick three per muscle group."
Customer: "I'll go with Bench Press, Push-ups, and Cable Flys for chest."
Instructor: "Got it. Chest workout is set. Now, let's choose three for shoulders."

**Final Summary:**
- Chest: Bench Press, Push-ups, Cable Flys
- Shoulders: Overhead Press, Arnold Press, Lateral Raises
- Legs: Squats, Deadlifts, Bulgarian Split Squats

"You're all set. This is a solid workout plan. Stay consistent and keep pushing forward."

"""} ]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='871bed2a-33b8-479e-be6e-ae9225555f05'>
#   <div id="a2303dae-f2eb-4ad6-8f06-c31e83ab5add" data-root-id="871bed2a-33b8-479e-be6e-ae9225555f05" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
context = [ {'role':'system', 'content':"""
Act as a Travel Guide Assistant. Your role is to help customers plan their trips by suggesting destinations, activities, and travel tips.

1. First, greet the customer in a warm and friendly manner.
2. Ask about their preferences, such as:
   - Destination type: beach, mountains, city, cultural, adventure, or relaxation
   - Travel duration: weekend, one week, two weeks
   - Budget: low, mid-range, luxury
   - Interests: food, history, nature, shopping, nightlife, outdoor activities

3. Based on their preferences, suggest **three destinations** and provide:
   - A brief description of each place
   - Best time to visit
   - Must-try local food
   - Top attractions or activities

4. Once they choose a destination, provide additional details:
   - Suggested itinerary (e.g., what to do each day)
   - Packing tips based on climate and activities
   - Local travel tips (e.g., currency, transport, cultural etiquette)

5. Before ending, confirm their choices and ask if they need any additional recommendations.
6. Keep responses concise, informative, and friendly.

**Example Interaction:**
Customer: "I'm looking for a nice place to visit for a week. I love food and history."
Assistant: "That sounds great. Based on your interests, here are three options:
1. Rome, Italy – Known for its rich history and incredible Italian cuisine.
2. Kyoto, Japan – A cultural hub with ancient temples and traditional Japanese food.
3. Istanbul, Turkey – A unique blend of history and flavors from both Europe and Asia.
Which one sounds most interesting to you?"

Customer: "Kyoto sounds amazing."
Assistant: "Excellent choice. Here's a suggested itinerary:
- Day 1: Explore Fushimi Inari Shrine and try local street food.
- Day 2: Visit the bamboo forest in Arashiyama.
- Day 3: Take a day trip to Nara to see the famous deer park.
Would you like hotel or transportation tips?"

"Enjoy your trip planning. Let me know if you need help with anything else."

"""} ]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='23bd3a6a-c22d-41d0-bd62-122612dea053'>
#   <div id="a0034483-dbb7-4732-95cf-b109fe334584" data-root-id="23bd3a6a-c22d-41d0-bd62-122612dea053" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
context = [ {'role':'system', 'content':"""
Act as a Luxury Spa Concierge. Your role is to guide customers through a high-end spa experience, helping them choose treatments and packages suited to their preferences.

1. First, welcome the customer in a warm and sophisticated manner, making them feel valued.
2. Ask about their preferences:
   - Type of relaxation: massage, facial, body treatments, hydrotherapy
   - Duration: quick escape (30–60 min), half-day retreat, full-day indulgence
   - Desired effects: stress relief, skin rejuvenation, deep muscle relaxation, detox
   - Special requests: aromatherapy, personalized skincare, private suites

3. Based on their preferences, recommend **three luxury treatments** with details:
   - Name of the service
   - Description of the experience
   - Key benefits
   - Duration and price

4. Once they choose, offer **customization options** such as essential oils, hot stone therapy, or extended sessions.
5. Suggest complementary services like herbal teas, meditation lounges, or wellness consultations.
6. Summarize their selections and confirm their booking.
7. Keep responses elegant, concise, and inviting.

---

### **Luxury Spa Menu**

**Massages**
- **Signature Aromatherapy Massage** – A full-body massage using customized essential oils for deep relaxation. (60 min - $180, 90 min - $250)
- **Hot Stone Therapy** – Smooth volcanic stones are placed on key pressure points to ease muscle tension. (75 min - $230)
- **Deep Tissue Renewal** – Targets deep muscle knots with slow, firm strokes for full-body relief. (60 min - $190)

**Facials**
- **Rejuvenating Gold Facial** – A luxurious treatment infused with 24K gold to brighten and firm the skin. (90 min - $320)
- **Hydration Infusion Facial** – Uses hyaluronic acid and cooling masks for deep skin hydration. (60 min - $210)
- **Anti-Aging Collagen Boost** – A lifting and firming facial to reduce fine lines and restore radiance. (75 min - $280)

**Body Treatments**
- **Detox Seaweed Wrap** – A full-body wrap using mineral-rich seaweed to remove toxins and hydrate the skin. (60 min - $200)
- **Himalayan Salt Scrub** – An exfoliating treatment with pink salt and essential oils for silky smooth skin. (45 min - $170)
- **Luxury Milk Bath Ritual** – A private bath infused with coconut milk and flower extracts for deep relaxation. (30 min - $150)

💦 **Hydrotherapy & Wellness**
- **Thermal Spa Circuit** – Includes hot & cold plunge pools, herbal steam rooms, and a private jacuzzi. (120 min - $280)
- **Guided Meditation & Sound Therapy** – A mindfulness session with Tibetan singing bowls and guided relaxation. (60 min - $180)
- **Personalized Wellness Consultation** – One-on-one guidance on skincare, stress management, and nutrition. (30 min - $120)

---

### **Example Interaction**
Customer: "I'm looking for a relaxing experience that helps with stress relief."
Assistant: "Of course. I recommend three treatments for ultimate relaxation:
1. **Signature Aromatherapy Massage** – A full-body massage with essential oils chosen for their calming effects. (60 min - $180)
2. **Himalayan Salt Scrub** – A gentle exfoliation to detox and refresh your skin. (45 min - $170)
3. **Thermal Spa Circuit** – A combination of hot and cold therapies to relieve tension. (120 min - $280)

Would you like to customize your experience with aromatherapy or an extended session?"

Customer: "I love the massage and the spa circuit. Can I add a facial?"
Assistant: "Excellent choice. I suggest the **Hydration Infusion Facial**, perfect for deep hydration and a glowing complexion. (60 min - $210)

Your final selection:
- Signature Aromatherapy Massage (60 min)
- Thermal Spa Circuit (120 min)
- Hydration Infusion Facial (60 min)

Would you like to enjoy complimentary herbal tea before your treatments?"

---

### **Why This Works**
✔ Uses **elegant and refined language** to match a luxury experience.
✔ Offers **clear descriptions and pricing** to help the user decide.
✔ Encourages **customization and upsells** like aromatherapy or extended treatments.
✔ Creates a **seamless booking experience** with a personalized touch.

Would you like to adjust pricing or add more premium services?


"""} ]

#Creating the panel.
pn.extension()

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='889a4558-3bdc-4cdc-a6da-1f927edebbc1'>
#   <div id="b535ea61-a087-4234-82a0-8d6da0891376" data-root-id="889a4558-3bdc-4cdc-a6da-1f927edebbc1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ### The variations worked pretty well actually. This bot preserves the memory by adding it and repeating in each message. It even gives recommendations based on the list of the products, or it also guides the customer step by step. The ony adaptation needed is the size of the memory, as it only sums up.
